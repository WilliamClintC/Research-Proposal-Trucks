# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\clint\Desktop\Research-Paper-Trucks\Exploration\2\df_exported_final.csv')
df
# Out:
#     REPORT_DATE  FATALITIES  COUNTY  change_2006_2016  indicator_2002_2006  \
# 0    2005-06-06           1   37185              -1.0                    1
# 1    2005-05-14           2   35057              -1.0                    1
# 2    2005-12-15           1   37159               0.0                    1
# 3    2005-12-09           1   32003              -3.0                    1
# 4    2005-07-28           1   34003              -1.0                    1
# ..          ...         ...     ...               ...                  ...
# 361  1995-08-27           2   47065               1.0                    0
# 362  1999-10-23           3   47089              -1.0                    0
# 363  2000-08-06           2   47055              -1.0                    0
# 364  1999-06-14           2   47145               0.0                    0
# 365  1999-06-03           5   47117               0.0                    0
#
# ...

# %%
df.groupby('simple_family')['FATALITIES'].describe()
# Out:
#                count      mean       std  min  25%  50%   75%  max
# simple_family
# Exclusion       21.0  1.142857  0.358569  1.0  1.0  1.0  1.00  2.0
# Reform         132.0  1.272727  0.731942  1.0  1.0  1.0  1.00  7.0
# Traditional    199.0  1.236181  0.688651  1.0  1.0  1.0  1.00  5.0
# Wild Texas      14.0  1.285714  0.468807  1.0  1.0  1.0  1.75  2.0

# %%
mean_fatalities = df.groupby('simple_family')['FATALITIES'].mean()
mean_fatalities.plot(kind='bar', title='Mean Fatalities by Simple Family')
# Out:
# <Axes: title={'center': 'Mean Fatalities by Simple Family'}, xlabel='simple_family'>

# %%
columns_to_drop = ['name', 'Longitude', 'Latitude', 'Region', 'Family', 'Color', 'Nearest Neighbor', 'Region_color']
df = df.drop(columns=columns_to_drop)
df
# Out:
#     REPORT_DATE  FATALITIES  COUNTY  change_2006_2016  indicator_2002_2006  \
# 0    2005-06-06           1   37185              -1.0                    1
# 1    2005-05-14           2   35057              -1.0                    1
# 2    2005-12-15           1   37159               0.0                    1
# 3    2005-12-09           1   32003              -3.0                    1
# 4    2005-07-28           1   34003              -1.0                    1
# ..          ...         ...     ...               ...                  ...
# 361  1995-08-27           2   47065               1.0                    0
# 362  1999-10-23           3   47089              -1.0                    0
# 363  2000-08-06           2   47055              -1.0                    0
# 364  1999-06-14           2   47145               0.0                    0
# 365  1999-06-03           5   47117               0.0                    0
#
#      indicator_1999_2001  indicator_1993_1998 simple_family
# ...

# %%
df.to_csv('df_exported.csv', index=False)
